# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
path = "/content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion"

# %%
files = os.listdir("/content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion")
print(files)
# Out:
# ['utils.py', 'Technical Information and Experimental Test Results for LG 18650HG2.pdf', 'Readme file - Description of Experimental Tests.txt', 'n10degC', '25degC', 'n20degC', '0degC', '10degC', '40degC']

# %%
import os
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
file = "/content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/567_Charge6.csv"
with open(file, "r", errors="replace") as f:
    for i in range(1, 36):
        line = f.readline()
        print(f"{i}: {line.rstrip()}")
# Out:
# 1:
# 2:
# 3: Measurement ID,567
# 4: Battery Name,LG HG2 18650_SN62A4
# 5: Battery Type,Li-ion
# 6: Circuit,Circuit001
# 7: Program,1747 - LG_HG2_CyclesA
# 8: Start Time,11/12/2018 5:21:50 PM
# 9: End Time,11/14/2018 10:05:51 AM
# 10: Test section,Charge6
# 11: Comment,
# 12: OrderNo,
# 13: Producer, LG
# 14: Type, Li-ion
# 15: Nominal Voltage, 3.7
# 16: Nominal Current, 3
# 17: Nominal Capacity, 3
# 18: Cells, 1
# 19: Maximum Voltage, 4.2
# 20: Gassing Voltage, 0
# 21: Break Voltage, 0
# 22: Charge Factor, 0
# 23: Impedance, 0.02
# 24: Cold Cranking Current, 0
# 25: Energy Density, 0
# 26: Comment,HG2 cell with 10AWG wire soldered  to cell
# 27:
# 28:
# 29: Time Stamp,Step,Status,Prog Time,Step Time,Cycle,Cycle Level,Procedure,Voltage,Current,Temperature,Capacity,WhAccu,Cnt,
# 30: ,,,,,,,,[V],[A],[C],[Ah],[Wh],[Cnt],
# 31: 11/13/2018 7:44:14 PM,3,PAU,26:22:23.416,00:01:00.000,0,0,NN_Char_Charge,3.24099,0.00000,10.72617,0.00000,0.00000,6.00000,
# 32: 11/13/2018 7:45:14 PM,3,PAU,26:23:23.419,00:02:00.003,0,0,NN_Char_Charge,3.24166,0.00000,13.77577,0.00000,0.00000,6.00000,
# 33: 11/13/2018 7:46:14 PM,3,PAU,26:24:23.417,00:03:00.001,0,0,NN_Char_Charge,3.24200,0.00000,17.14084,0.00000,0.00000,6.00000,
# 34: 11/13/2018 7:47:14 PM,3,PAU,26:25:23.420,00:04:00.004,0,0,NN_Char_Charge,3.24234,0.00000,20.29560,0.00000,0.00000,6.00000,
# 35: 11/13/2018 7:48:14 PM,3,PAU,26:26:23.421,00:05:00.005,0,0,NN_Char_Charge,3.24268,0.00000,21.87297,0.00000,0.00000,6.00000,

# %%
data_folder = "/content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion"
csv_files = []
for root, dirs, files in os.walk(data_folder):
    for file in files:
        if file.lower().endswith(".csv"):
            csv_files.append(os.path.join(root, file))
print("Total CSV files found:", len(csv_files))
for file in csv_files:
    print(file)
# Out:
# Total CSV files found: 208
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/596_Cap_1C.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/593_HPPC.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/601_Charge8.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/596_Charge5.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/601_US06.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/596_Charge4.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/602_Cap_1C.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/596_Charge2.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/604_Charge16.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/604_Charge14.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/604_Charge13.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/602_Mixed5.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/596_Charge1.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/601_Charge7.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/593_Dis_2C.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/602_Charge11.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/602_Charge10.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/596_UDDS.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/593_Dis_0p5C.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/604_Charge17.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/604_Charge10.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/601_Mixed2.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/602_Charge17.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/593_C20DisCh.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/604_Charge15.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/596_HWFET.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/596_Charge3.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/596_LA92.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/601_Charge6.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/604_Mixed3.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/601_Mixed1.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/604_Charge9.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/602_Charge12.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/602_Mixed4.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/604_PausCycl.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/604_Mixed6.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/604_Mixed8.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n10degC/604_Mixed7.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/552_Charge11.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/552_Cap_1C.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/549_Dis_0p5C.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/549_Charge.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/552_Charge15.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/552_Charge16.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/551_Charge6.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/551_Mixed2.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/552_Charge14.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/551_Charge8.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/552_Charge12.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/552_Mixed3.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/552_Charge9.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/549_C20DisCh.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/551_Charge1.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/551_Charge4.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/551_LA92.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/551_US06.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/551_Charge3.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/552_Charge10.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/551_Charge7.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/551_HWFET.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/549_HPPC.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/552_Charge13.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/551_Charge5.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/551_Cap_1C.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/551_Charge2.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/549_Dis_2C.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/551_Mixed1.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/551_UDDS.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/552_Mixed8.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/552_Mixed5.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/552_Mixed4.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/552_Mixed6.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/552_PausCycl.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/25degC/552_Mixed7.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/611_Charge11.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/610_Charge8.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/610_Mixed1.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/611_Cap_1C.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/610_UDDS.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/611_Mixed3.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/610_Mixed2.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/610_Charge1.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/610_Charge7.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/610_US06.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/610_Charge3.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/611_Charge12.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/611_Charge10.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/611_Mixed7.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/611_Mixed5.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/607_Dis_2C.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/611_Mixed4.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/611_Mixed6.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/611_Charge9.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/607_C20DisCh.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/611_Charge13.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/607_Dis_0p5C.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/610_LA92.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/610_Charge6.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/610_HWFET.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/610_Charge5.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/611_Charge17.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/610_Cap_1C.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/611_Charge14.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/607_HPPC.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/611_Charge15.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/610_Charge2.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/610_Charge4.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/611_PausCycl.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/n20degC/611_Mixed8.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/0degC/589_HWFET.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/0degC/589_LA92.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/0degC/589_Charge3.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/0degC/590_Charge13.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/0degC/585_C20DisCh.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/0degC/585_Dis_2C.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/0degC/590_Charge16.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/0degC/589_Charge2.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/0degC/590_Charge14.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/0degC/589_Charge8.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/0degC/590_Mixed4.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/0degC/585_HPPC.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/0degC/589_Mixed2.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/0degC/589_UDDS.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/0degC/589_Charge6.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/0degC/590_Charge15.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/0degC/589_Charge1.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/0degC/589_Cap_1C.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/0degC/590_Charge10.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/0degC/589_Charge4.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/0degC/590_Charge12.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/0degC/585_Dis_0p5C.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/0degC/589_Charge7.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/0degC/590_Mixed6.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/0degC/589_US06.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/0degC/590_Mixed5.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/0degC/589_Charge5.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/0degC/589_Mixed1.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/0degC/590_Charge11.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/0degC/590_Mixed7.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/0degC/590_Mixed8.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/0degC/590_PausCycl.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/571_Mixed4.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/567_Mixed2.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/571_PausCycl.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/571_Cap_1C.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/576_Charge4.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/575_Dis_0p5C.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/571_Charge15.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/571_Charge10.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/576_Charge2.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/571_Mixed6.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/571_Mixed7.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/571_Charge11.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/567_Mixed1.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/576_Cap_1C.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/576_Charge1.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/576_HWFET.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/567_Charge6.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/567_Charge8.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/575_C20DisCh.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/567_US06.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/567_Charge7.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/575_Dis_2C.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/571_Charge13.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/575_HPPC.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/571_Charge12.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/571_Charge14.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/571_Mixed8.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/571_Mixed5.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/576_Charge3.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/571_Charge16.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/582_LA92.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/10degC/576_UDDS.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/557_Charge10.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/556_Charge8.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/555_Dis_0p5C.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/557_Charge9.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/557_Cap_1C.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/556_US06.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/556_LA92.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/555_HPPC.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/556_Charge2.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/556_Charge1.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/556_Charge5.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/556_UDDS.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/556_Charge7.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/556_Mixed2.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/556_HWFET.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/555_Dis_2C.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/556_Charge3.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/556_Charge6.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/556_Mixed1.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/556_Charge4.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/555_C20DisCh.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/562_Mixed8.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/562_Mixed4.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/562_Charge16.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/562_Charge15.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/562_Mixed6.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/562_Mixed5.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/562_Charge10.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/562_PausCycl.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/557_Mixed3.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/562_Charge12.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/562_Charge13.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/562_Charge14.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/562_Charge11.csv
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion/40degC/562_Mixed7.csv

# %%
dataframes = {}
for file in csv_files:
    file_name = os.path.basename(file)
    try:
        with open(
            file,
            "r",
            encoding="utf-8",
            errors="ignore"
        ) as f:

            lines = f.readlines()
        header_index = None
        for i, line in enumerate(lines):
            line_lower = line.lower()
            if (
                "voltage" in line_lower
                and "current" in line_lower
                and "temperature" in line_lower
            ):
                header_index = i
                break
        if header_index is None:
            print("Measurement header not found:",file_name)
            continue
        from io import StringIO
        measurement_text = "".join(
            lines[header_index:]
        )

        df = pd.read_csv(
            StringIO(measurement_text)
        )
        if len(df) > 0:
            first_row = df.iloc[0].astype(str).str.strip()
            unit_values = first_row.str.lower().tolist()
            if (
                "v" in unit_values
                or "a" in unit_values
                or any("°c" in x for x in unit_values)
            ):
                df = df.iloc[1:].reset_index(drop=True)
        df.columns = (
            df.columns
            .astype(str)
            .str.strip())
        df = df.dropna(
            axis=1,
            how="all")
        dataframes[file_name] = df
        print("Loaded:",file_name,"| Header row:",header_index + 1,"| Rows:",df.shape[0],"| Columns:",df.shape[1])
    except Exception as e:
        print("Could not read:",file_name)
        print("Reason:",e)
print("LOADING SUMMARY")
print("Total CSV files found:",len(csv_files))
print("Successfully loaded:",len(dataframes))
# Out:
# Loaded: 596_Cap_1C.csv | Header row: 29 | Rows: 342 | Columns: 14
# Loaded: 593_HPPC.csv | Header row: 29 | Rows: 40085 | Columns: 14
# Loaded: 601_Charge8.csv | Header row: 29 | Rows: 203 | Columns: 14
# Loaded: 596_Charge5.csv | Header row: 29 | Rows: 203 | Columns: 14
# Loaded: 601_US06.csv | Header row: 29 | Rows: 31914 | Columns: 14
# Loaded: 596_Charge4.csv | Header row: 29 | Rows: 203 | Columns: 14
# Loaded: 602_Cap_1C.csv | Header row: 29 | Rows: 338 | Columns: 14
# Loaded: 596_Charge2.csv | Header row: 29 | Rows: 205 | Columns: 14
# Loaded: 604_Charge16.csv | Header row: 29 | Rows: 154 | Columns: 14
# Loaded: 604_Charge14.csv | Header row: 29 | Rows: 202 | Columns: 14
# Loaded: 604_Charge13.csv | Header row: 29 | Rows: 202 | Columns: 14
# Loaded: 602_Mixed5.csv | Header row: 29 | Rows: 60088 | Columns: 14
# Loaded: 596_Charge1.csv | Header row: 29 | Rows: 132 | Columns: 14
# Loaded: 601_Charge7.csv | Header row: 29 | Rows: 202 | Columns: 14
# Loaded: 593_Dis_2C.csv | Header row: 29 | Rows: 220 | Columns: 14
# Loaded: 602_Charge11.csv | Header row: 29 | Rows: 203 | Columns: 14
# Loaded: 602_Charge10.csv | Header row: 29 | Rows: 204 | Columns: 14
# Loaded: 596_UDDS.csv | Header row: 29 | Rows: 123603 | Columns: 14
# Loaded: 593_Dis_0p5C.csv | Header row: 29 | Rows: 303 | Columns: 14
# Loaded: 604_Charge17.csv | Header row: 29 | Rows: 141 | Columns: 14
# Loaded: 604_Charge10.csv | Header row: 29 | Rows: 203 | Columns: 14
# Loaded: 601_Mixed2.csv | Header row: 29 | Rows: 65255 | Columns: 14
# Loaded: 602_Charge17.csv | Header row: 29 | Rows: 132 | Columns: 14
# Loaded: 593_C20DisCh.csv | Header row: 29 | Rows: 2207 | Columns: 14
# Loaded: 604_Charge15.csv | Header row: 29 | Rows: 202 | Columns: 14
# Loaded: 596_HWFET.csv | Header row: 29 | Rows: 44904 | Columns: 14
# Loaded: 596_Charge3.csv | Header row: 29 | Rows: 203 | Columns: 14
# Loaded: 596_LA92.csv | Header row: 29 | Rows: 72099 | Columns: 14
# Loaded: 601_Charge6.csv | Header row: 29 | Rows: 202 | Columns: 14
# Loaded: 604_Mixed3.csv | Header row: 29 | Rows: 55215 | Columns: 14
# Loaded: 601_Mixed1.csv | Header row: 29 | Rows: 62623 | Columns: 14
# Loaded: 604_Charge9.csv | Header row: 29 | Rows: 205 | Columns: 14
# Loaded: 602_Charge12.csv | Header row: 29 | Rows: 202 | Columns: 14
# Loaded: 602_Mixed4.csv | Header row: 29 | Rows: 65678 | Columns: 14
# Loaded: 604_PausCycl.csv | Header row: 29 | Rows: 22151 | Columns: 14
# Loaded: 604_Mixed6.csv | Header row: 29 | Rows: 55969 | Columns: 14
# Loaded: 604_Mixed8.csv | Header row: 29 | Rows: 67326 | Columns: 14
# Loaded: 604_Mixed7.csv | Header row: 29 | Rows: 55941 | Columns: 14
# Loaded: 552_Charge11.csv | Header row: 29 | Rows: 210 | Columns: 14
# Loaded: 552_Cap_1C.csv | Header row: 29 | Rows: 394 | Columns: 14
# Loaded: 549_Dis_0p5C.csv | Header row: 29 | Rows: 112 | Columns: 14
# Loaded: 549_Charge.csv | Header row: 27 | Rows: 858 | Columns: 14
# Loaded: 552_Charge15.csv | Header row: 29 | Rows: 210 | Columns: 14
# Loaded: 552_Charge16.csv | Header row: 29 | Rows: 129 | Columns: 14
# Loaded: 551_Charge6.csv | Header row: 29 | Rows: 211 | Columns: 14
# Loaded: 551_Mixed2.csv | Header row: 29 | Rows: 79173 | Columns: 14
# Loaded: 552_Charge14.csv | Header row: 29 | Rows: 210 | Columns: 14
# Loaded: 551_Charge8.csv | Header row: 29 | Rows: 212 | Columns: 14
# Loaded: 552_Charge12.csv | Header row: 29 | Rows: 210 | Columns: 14
# Loaded: 552_Mixed3.csv | Header row: 29 | Rows: 73828 | Columns: 14
# Loaded: 552_Charge9.csv | Header row: 29 | Rows: 214 | Columns: 14
# Loaded: 549_C20DisCh.csv | Header row: 29 | Rows: 2424 | Columns: 14
# Loaded: 551_Charge1.csv | Header row: 29 | Rows: 131 | Columns: 14
# Loaded: 551_Charge4.csv | Header row: 29 | Rows: 131 | Columns: 14
# Loaded: 551_LA92.csv | Header row: 29 | Rows: 100765 | Columns: 14
# Loaded: 551_US06.csv | Header row: 29 | Rows: 40156 | Columns: 14
# Loaded: 551_Charge3.csv | Header row: 29 | Rows: 211 | Columns: 14
# Loaded: 552_Charge10.csv | Header row: 29 | Rows: 210 | Columns: 14
# Loaded: 551_Charge7.csv | Header row: 29 | Rows: 211 | Columns: 14
# Loaded: 551_HWFET.csv | Header row: 29 | Rows: 6003 | Columns: 14
# Loaded: 549_HPPC.csv | Header row: 29 | Rows: 48049 | Columns: 14
# Loaded: 552_Charge13.csv | Header row: 29 | Rows: 210 | Columns: 14
# Loaded: 551_Charge5.csv | Header row: 29 | Rows: 211 | Columns: 14
# Loaded: 551_Cap_1C.csv | Header row: 29 | Rows: 398 | Columns: 14
# Loaded: 551_Charge2.csv | Header row: 29 | Rows: 214 | Columns: 14
# Loaded: 549_Dis_2C.csv | Header row: 29 | Rows: 28 | Columns: 14
# Loaded: 551_Mixed1.csv | Header row: 29 | Rows: 77228 | Columns: 14
# Loaded: 551_UDDS.csv | Header row: 29 | Rows: 159647 | Columns: 14
# Loaded: 552_Mixed8.csv | Header row: 29 | Rows: 85916 | Columns: 14
# Loaded: 552_Mixed5.csv | Header row: 29 | Rows: 72185 | Columns: 14
# Loaded: 552_Mixed4.csv | Header row: 29 | Rows: 80851 | Columns: 14
# Loaded: 552_Mixed6.csv | Header row: 29 | Rows: 78107 | Columns: 14
# Loaded: 552_PausCycl.csv | Header row: 29 | Rows: 63020 | Columns: 14
# Loaded: 552_Mixed7.csv | Header row: 29 | Rows: 73236 | Columns: 14
# Loaded: 611_Charge11.csv | Header row: 29 | Rows: 191 | Columns: 14
# Loaded: 610_Charge8.csv | Header row: 29 | Rows: 193 | Columns: 14
# Loaded: 610_Mixed1.csv | Header row: 29 | Rows: 45344 | Columns: 14
# Loaded: 611_Cap_1C.csv | Header row: 29 | Rows: 265 | Columns: 14
# Loaded: 610_UDDS.csv | Header row: 29 | Rows: 81912 | Columns: 14
# Loaded: 611_Mixed3.csv | Header row: 29 | Rows: 45164 | Columns: 14
# Loaded: 610_Mixed2.csv | Header row: 29 | Rows: 43044 | Columns: 14
# Loaded: 610_Charge1.csv | Header row: 29 | Rows: 131 | Columns: 14
# Loaded: 610_Charge7.csv | Header row: 29 | Rows: 192 | Columns: 14
# Loaded: 610_US06.csv | Header row: 29 | Rows: 27607 | Columns: 14
# Loaded: 610_Charge3.csv | Header row: 29 | Rows: 191 | Columns: 14
# Loaded: 611_Charge12.csv | Header row: 29 | Rows: 191 | Columns: 14
# Loaded: 611_Charge10.csv | Header row: 29 | Rows: 192 | Columns: 14
# Loaded: 611_Mixed7.csv | Header row: 29 | Rows: 40684 | Columns: 14
# Loaded: 611_Mixed5.csv | Header row: 29 | Rows: 45459 | Columns: 14
# Loaded: 607_Dis_2C.csv | Header row: 29 | Rows: 200 | Columns: 14
# Loaded: 611_Mixed4.csv | Header row: 29 | Rows: 46054 | Columns: 14
# Loaded: 611_Mixed6.csv | Header row: 29 | Rows: 44197 | Columns: 14
# Loaded: 611_Charge9.csv | Header row: 29 | Rows: 193 | Columns: 14
# Loaded: 607_C20DisCh.csv | Header row: 29 | Rows: 2151 | Columns: 14
# Loaded: 611_Charge13.csv | Header row: 29 | Rows: 191 | Columns: 14
# Loaded: 607_Dis_0p5C.csv | Header row: 29 | Rows: 284 | Columns: 14
# Loaded: 610_LA92.csv | Header row: 29 | Rows: 52486 | Columns: 14
# Loaded: 610_Charge6.csv | Header row: 29 | Rows: 192 | Columns: 14
# Loaded: 610_HWFET.csv | Header row: 29 | Rows: 33346 | Columns: 14
# Loaded: 610_Charge5.csv | Header row: 29 | Rows: 191 | Columns: 14
# Loaded: 611_Charge17.csv | Header row: 29 | Rows: 132 | Columns: 14
# Loaded: 610_Cap_1C.csv | Header row: 29 | Rows: 271 | Columns: 14
# Loaded: 611_Charge14.csv | Header row: 29 | Rows: 191 | Columns: 14
# Loaded: 607_HPPC.csv | Header row: 29 | Rows: 36068 | Columns: 14
# Loaded: 611_Charge15.csv | Header row: 29 | Rows: 191 | Columns: 14
# Loaded: 610_Charge2.csv | Header row: 29 | Rows: 194 | Columns: 14
# Loaded: 610_Charge4.csv | Header row: 29 | Rows: 191 | Columns: 14
# Loaded: 611_PausCycl.csv | Header row: 29 | Rows: 16618 | Columns: 14
# Loaded: 611_Mixed8.csv | Header row: 29 | Rows: 46764 | Columns: 14
# Loaded: 589_HWFET.csv | Header row: 29 | Rows: 49679 | Columns: 14
# Loaded: 589_LA92.csv | Header row: 29 | Rows: 81578 | Columns: 14
# Loaded: 589_Charge3.csv | Header row: 29 | Rows: 207 | Columns: 14
# Loaded: 590_Charge13.csv | Header row: 29 | Rows: 206 | Columns: 14
# Loaded: 585_C20DisCh.csv | Header row: 29 | Rows: 2245 | Columns: 14
# Loaded: 585_Dis_2C.csv | Header row: 29 | Rows: 231 | Columns: 14
# Loaded: 590_Charge16.csv | Header row: 29 | Rows: 154 | Columns: 14
# Loaded: 589_Charge2.csv | Header row: 29 | Rows: 208 | Columns: 14
# Loaded: 590_Charge14.csv | Header row: 29 | Rows: 206 | Columns: 14
# Loaded: 589_Charge8.csv | Header row: 29 | Rows: 207 | Columns: 14
# Loaded: 590_Mixed4.csv | Header row: 29 | Rows: 68028 | Columns: 14
# Loaded: 585_HPPC.csv | Header row: 29 | Rows: 40220 | Columns: 14
# Loaded: 589_Mixed2.csv | Header row: 29 | Rows: 72304 | Columns: 14
# Loaded: 589_UDDS.csv | Header row: 29 | Rows: 140436 | Columns: 14
# Loaded: 589_Charge6.csv | Header row: 29 | Rows: 206 | Columns: 14
# Loaded: 590_Charge15.csv | Header row: 29 | Rows: 206 | Columns: 14
# Loaded: 589_Charge1.csv | Header row: 29 | Rows: 132 | Columns: 14
# Loaded: 589_Cap_1C.csv | Header row: 29 | Rows: 367 | Columns: 14
# Loaded: 590_Charge10.csv | Header row: 29 | Rows: 209 | Columns: 14
# Loaded: 589_Charge4.csv | Header row: 29 | Rows: 206 | Columns: 14
# Loaded: 590_Charge12.csv | Header row: 29 | Rows: 206 | Columns: 14
# Loaded: 585_Dis_0p5C.csv | Header row: 29 | Rows: 311 | Columns: 14
# Loaded: 589_Charge7.csv | Header row: 29 | Rows: 207 | Columns: 14
# Loaded: 590_Mixed6.csv | Header row: 29 | Rows: 62484 | Columns: 14
# Loaded: 589_US06.csv | Header row: 29 | Rows: 33807 | Columns: 14
# Loaded: 590_Mixed5.csv | Header row: 29 | Rows: 64996 | Columns: 14
# Loaded: 589_Charge5.csv | Header row: 29 | Rows: 207 | Columns: 14
# Loaded: 589_Mixed1.csv | Header row: 29 | Rows: 67313 | Columns: 14
# Loaded: 590_Charge11.csv | Header row: 29 | Rows: 206 | Columns: 14
# Loaded: 590_Mixed7.csv | Header row: 29 | Rows: 61541 | Columns: 14
# Loaded: 590_Mixed8.csv | Header row: 29 | Rows: 75839 | Columns: 14
# Loaded: 590_PausCycl.csv | Header row: 29 | Rows: 26302 | Columns: 14
# Loaded: 571_Mixed4.csv | Header row: 29 | Rows: 73930 | Columns: 14
# Loaded: 567_Mixed2.csv | Header row: 29 | Rows: 77753 | Columns: 14
# Loaded: 571_PausCycl.csv | Header row: 29 | Rows: 27832 | Columns: 14
# Loaded: 571_Cap_1C.csv | Header row: 29 | Rows: 369 | Columns: 14
# Loaded: 576_Charge4.csv | Header row: 29 | Rows: 207 | Columns: 14
# Loaded: 575_Dis_0p5C.csv | Header row: 29 | Rows: 319 | Columns: 14
# Loaded: 571_Charge15.csv | Header row: 29 | Rows: 207 | Columns: 14
# Loaded: 571_Charge10.csv | Header row: 29 | Rows: 209 | Columns: 14
# Loaded: 576_Charge2.csv | Header row: 29 | Rows: 210 | Columns: 14
# Loaded: 571_Mixed6.csv | Header row: 29 | Rows: 73922 | Columns: 14
# Loaded: 571_Mixed7.csv | Header row: 29 | Rows: 69326 | Columns: 14
# Loaded: 571_Charge11.csv | Header row: 29 | Rows: 207 | Columns: 14
# Loaded: 567_Mixed1.csv | Header row: 29 | Rows: 72330 | Columns: 14
# Loaded: 576_Cap_1C.csv | Header row: 29 | Rows: 376 | Columns: 14
# Loaded: 576_Charge1.csv | Header row: 29 | Rows: 131 | Columns: 14
# Loaded: 576_HWFET.csv | Header row: 29 | Rows: 52879 | Columns: 14
# Loaded: 567_Charge6.csv | Header row: 29 | Rows: 208 | Columns: 14
# Loaded: 567_Charge8.csv | Header row: 29 | Rows: 209 | Columns: 14
# Loaded: 575_C20DisCh.csv | Header row: 29 | Rows: 2338 | Columns: 14
# Loaded: 567_US06.csv | Header row: 29 | Rows: 38719 | Columns: 14
# Loaded: 567_Charge7.csv | Header row: 29 | Rows: 209 | Columns: 14
# Loaded: 575_Dis_2C.csv | Header row: 29 | Rows: 237 | Columns: 14
# Loaded: 571_Charge13.csv | Header row: 29 | Rows: 207 | Columns: 14
# Loaded: 575_HPPC.csv | Header row: 29 | Rows: 44220 | Columns: 14
# Loaded: 571_Charge12.csv | Header row: 29 | Rows: 206 | Columns: 14
# Loaded: 571_Charge14.csv | Header row: 29 | Rows: 207 | Columns: 14
# Loaded: 571_Mixed8.csv | Header row: 29 | Rows: 81423 | Columns: 14
# Loaded: 571_Mixed5.csv | Header row: 29 | Rows: 67175 | Columns: 14
# Loaded: 576_Charge3.csv | Header row: 29 | Rows: 207 | Columns: 14
# Loaded: 571_Charge16.csv | Header row: 29 | Rows: 153 | Columns: 14
# Loaded: 582_LA92.csv | Header row: 29 | Rows: 90741 | Columns: 14
# Loaded: 576_UDDS.csv | Header row: 29 | Rows: 148899 | Columns: 14
# Loaded: 557_Charge10.csv | Header row: 29 | Rows: 34 | Columns: 14
# Loaded: 556_Charge8.csv | Header row: 29 | Rows: 211 | Columns: 14
# Loaded: 555_Dis_0p5C.csv | Header row: 29 | Rows: 319 | Columns: 14
# Loaded: 557_Charge9.csv | Header row: 29 | Rows: 209 | Columns: 14
# Loaded: 557_Cap_1C.csv | Header row: 29 | Rows: 370 | Columns: 14
# Loaded: 556_US06.csv | Header row: 29 | Rows: 39962 | Columns: 14
# Loaded: 556_LA92.csv | Header row: 29 | Rows: 98638 | Columns: 14
# Loaded: 555_HPPC.csv | Header row: 29 | Rows: 44520 | Columns: 14
# Loaded: 556_Charge2.csv | Header row: 29 | Rows: 213 | Columns: 14
# Loaded: 556_Charge1.csv | Header row: 29 | Rows: 132 | Columns: 14
# Loaded: 556_Charge5.csv | Header row: 29 | Rows: 210 | Columns: 14
# Loaded: 556_UDDS.csv | Header row: 29 | Rows: 158957 | Columns: 14
# Loaded: 556_Charge7.csv | Header row: 29 | Rows: 210 | Columns: 14
# Loaded: 556_Mixed2.csv | Header row: 29 | Rows: 78957 | Columns: 14
# Loaded: 556_HWFET.csv | Header row: 29 | Rows: 55911 | Columns: 14
# Loaded: 555_Dis_2C.csv | Header row: 29 | Rows: 239 | Columns: 14
# Loaded: 556_Charge3.csv | Header row: 29 | Rows: 210 | Columns: 14
# Loaded: 556_Charge6.csv | Header row: 29 | Rows: 210 | Columns: 14
# Loaded: 556_Mixed1.csv | Header row: 29 | Rows: 75342 | Columns: 14
# Loaded: 556_Charge4.csv | Header row: 29 | Rows: 210 | Columns: 14
# Loaded: 555_C20DisCh.csv | Header row: 29 | Rows: 2343 | Columns: 14
# Loaded: 562_Mixed8.csv | Header row: 29 | Rows: 14386 | Columns: 14
# Loaded: 562_Mixed4.csv | Header row: 29 | Rows: 11328 | Columns: 14
# Loaded: 562_Charge16.csv | Header row: 29 | Rows: 136 | Columns: 14
# Loaded: 562_Charge15.csv | Header row: 29 | Rows: 145 | Columns: 14
# Loaded: 562_Mixed6.csv | Header row: 29 | Rows: 11762 | Columns: 14
# Loaded: 562_Mixed5.csv | Header row: 29 | Rows: 13088 | Columns: 14
# Loaded: 562_Charge10.csv | Header row: 29 | Rows: 433 | Columns: 14
# Loaded: 562_PausCycl.csv | Header row: 29 | Rows: 7926 | Columns: 14
# Loaded: 557_Mixed3.csv | Header row: 29 | Rows: 67626 | Columns: 14
# Loaded: 562_Charge12.csv | Header row: 29 | Rows: 144 | Columns: 14
# Loaded: 562_Charge13.csv | Header row: 29 | Rows: 145 | Columns: 14
# Loaded: 562_Charge14.csv | Header row: 29 | Rows: 144 | Columns: 14
# Loaded: 562_Charge11.csv | Header row: 29 | Rows: 145 | Columns: 14
# Loaded: 562_Mixed7.csv | Header row: 29 | Rows: 7849 | Columns: 14
# LOADING SUMMARY
# Total CSV files found: 208
# Successfully loaded: 208

# %%
print("COLUMN STRUCTURE ACROSS ALL CSV FILES")
column_summary = []
for file_name, df in dataframes.items():
    column_summary.append({
        "File": file_name,
        "Columns": list(df.columns)
    })
column_summary_df = pd.DataFrame(column_summary)
print("\nTotal loaded files:", len(column_summary_df))
for _, row in column_summary_df.iterrows():
    print("\nFILE:", row["File"])
    print("COLUMNS:", row["Columns"])
# Out:
# COLUMN STRUCTURE ACROSS ALL CSV FILES
#
# Total loaded files: 208
#
# FILE: 596_Cap_1C.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 593_HPPC.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 601_Charge8.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 596_Charge5.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 601_US06.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 596_Charge4.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 602_Cap_1C.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 596_Charge2.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 604_Charge16.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 604_Charge14.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 604_Charge13.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 602_Mixed5.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 596_Charge1.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 601_Charge7.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 593_Dis_2C.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 602_Charge11.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 602_Charge10.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 596_UDDS.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 593_Dis_0p5C.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 604_Charge17.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 604_Charge10.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 601_Mixed2.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 602_Charge17.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 593_C20DisCh.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 604_Charge15.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 596_HWFET.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 596_Charge3.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 596_LA92.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 601_Charge6.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 604_Mixed3.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 601_Mixed1.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 604_Charge9.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 602_Charge12.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 602_Mixed4.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 604_PausCycl.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 604_Mixed6.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 604_Mixed8.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 604_Mixed7.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 552_Charge11.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 552_Cap_1C.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 549_Dis_0p5C.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 549_Charge.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 552_Charge15.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 552_Charge16.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 551_Charge6.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 551_Mixed2.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 552_Charge14.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 551_Charge8.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 552_Charge12.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 552_Mixed3.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 552_Charge9.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 549_C20DisCh.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 551_Charge1.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 551_Charge4.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 551_LA92.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 551_US06.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 551_Charge3.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 552_Charge10.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 551_Charge7.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 551_HWFET.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 549_HPPC.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 552_Charge13.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 551_Charge5.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 551_Cap_1C.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 551_Charge2.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 549_Dis_2C.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 551_Mixed1.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 551_UDDS.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 552_Mixed8.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 552_Mixed5.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 552_Mixed4.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 552_Mixed6.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 552_PausCycl.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 552_Mixed7.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 611_Charge11.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 610_Charge8.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 610_Mixed1.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 611_Cap_1C.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 610_UDDS.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 611_Mixed3.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 610_Mixed2.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 610_Charge1.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 610_Charge7.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 610_US06.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 610_Charge3.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 611_Charge12.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 611_Charge10.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 611_Mixed7.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 611_Mixed5.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 607_Dis_2C.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 611_Mixed4.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 611_Mixed6.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 611_Charge9.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 607_C20DisCh.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 611_Charge13.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 607_Dis_0p5C.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 610_LA92.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 610_Charge6.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 610_HWFET.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 610_Charge5.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 611_Charge17.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 610_Cap_1C.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 611_Charge14.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 607_HPPC.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 611_Charge15.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 610_Charge2.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 610_Charge4.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 611_PausCycl.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 611_Mixed8.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 589_HWFET.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 589_LA92.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 589_Charge3.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 590_Charge13.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 585_C20DisCh.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 585_Dis_2C.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 590_Charge16.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 589_Charge2.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 590_Charge14.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 589_Charge8.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 590_Mixed4.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 585_HPPC.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 589_Mixed2.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 589_UDDS.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 589_Charge6.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 590_Charge15.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 589_Charge1.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 589_Cap_1C.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 590_Charge10.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 589_Charge4.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 590_Charge12.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 585_Dis_0p5C.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 589_Charge7.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 590_Mixed6.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 589_US06.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 590_Mixed5.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 589_Charge5.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 589_Mixed1.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 590_Charge11.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 590_Mixed7.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 590_Mixed8.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 590_PausCycl.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 571_Mixed4.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 567_Mixed2.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 571_PausCycl.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 571_Cap_1C.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 576_Charge4.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 575_Dis_0p5C.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 571_Charge15.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 571_Charge10.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 576_Charge2.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 571_Mixed6.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 571_Mixed7.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 571_Charge11.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 567_Mixed1.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 576_Cap_1C.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 576_Charge1.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 576_HWFET.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 567_Charge6.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 567_Charge8.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 575_C20DisCh.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 567_US06.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 567_Charge7.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 575_Dis_2C.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 571_Charge13.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 575_HPPC.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 571_Charge12.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 571_Charge14.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 571_Mixed8.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 571_Mixed5.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 576_Charge3.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 571_Charge16.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 582_LA92.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 576_UDDS.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 557_Charge10.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 556_Charge8.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 555_Dis_0p5C.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 557_Charge9.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 557_Cap_1C.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 556_US06.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 556_LA92.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 555_HPPC.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 556_Charge2.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 556_Charge1.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 556_Charge5.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 556_UDDS.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 556_Charge7.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 556_Mixed2.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 556_HWFET.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 555_Dis_2C.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 556_Charge3.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 556_Charge6.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 556_Mixed1.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 556_Charge4.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 555_C20DisCh.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 562_Mixed8.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 562_Mixed4.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 562_Charge16.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 562_Charge15.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 562_Mixed6.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 562_Mixed5.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 562_Charge10.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 562_PausCycl.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 557_Mixed3.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 562_Charge12.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 562_Charge13.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 562_Charge14.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 562_Charge11.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']
#
# FILE: 562_Mixed7.csv
# COLUMNS: ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt']

# %%
file_summary = []
for file_name, df in dataframes.items():
    file_summary.append({
        "File Name": file_name,
        "Rows": len(df),
        "Columns": len(df.columns),
        "Column Names": ", ".join(
            df.columns.astype(str))})
file_summary_df = pd.DataFrame(
    file_summary
)
print("\nFirst few files:")
print(file_summary_df.head())
print("\nTotal measurement rows across all files:",file_summary_df["Rows"].sum())
# Out:
# First few files:
#          File Name   Rows  Columns  \
# 0   596_Cap_1C.csv    342       14
# 1     593_HPPC.csv  40085       14
# 2  601_Charge8.csv    203       14
# 3  596_Charge5.csv    203       14
# 4     601_US06.csv  31914       14
#
#                                         Column Names
# 0  Time Stamp, Step, Status, Prog Time, Step Time...
# 1  Time Stamp, Step, Status, Prog Time, Step Time...
# 2  Time Stamp, Step, Status, Prog Time, Step Time...
# 3  Time Stamp, Step, Status, Prog Time, Step Time...
# 4  Time Stamp, Step, Status, Prog Time, Step Time...
#
# Total measurement rows across all files: 4955125

# %%
combined_data = []
for file_name, df in dataframes.items():
    temp = df.copy()
    temp["File Name"] = file_name
    combined_data.append(temp)
if combined_data:
    data = pd.concat(
        combined_data,
        ignore_index=True,
        sort=False
    )
else:
    data = pd.DataFrame()
print("\nCombined dataset shape:")
print(data.shape)
print("\nCombined dataset columns:")
print(data.columns.tolist())
# Out:
# Combined dataset shape:
# (4955125, 15)
#
# Combined dataset columns:
# ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt', 'File Name']

# %%
data.columns = (
    data.columns
    .astype(str)
    .str.strip()
)
def find_column(possible_names):
    for column in data.columns:
        column_clean = (
            str(column)
            .strip()
            .lower()
            .replace("_", "")
            .replace(" ", "")
        )
        for name in possible_names:
            name_clean = (
                name
                .lower()
                .replace("_", "")
                .replace(" ", "")
            )
            if column_clean == name_clean:
                return column
    return None
voltage_col = find_column(["Voltage"])
current_col = find_column(["Current"])
temperature_col = find_column(["Temperature"])
capacity_col = find_column(["Capacity"])
time_col = find_column(["Time Stamp","Time","Prog Time","Step Time"])
soc_col = find_column(["SOC","State of Charge"])
print("IMPORTANT COLUMN DETECTION")
print("Voltage column:", voltage_col)
print("Current column:", current_col)
print("Temperature column:", temperature_col)
print("Capacity column:", capacity_col)
print("Time column:", time_col)
print("SOC column:", soc_col)
# Out:
# IMPORTANT COLUMN DETECTION
# Voltage column: Voltage
# Current column: Current
# Temperature column: Temperature
# Capacity column: Capacity
# Time column: Time Stamp
# SOC column: None

# %%
numeric_columns = [voltage_col,current_col,temperature_col,capacity_col,soc_col]
for column in numeric_columns:
    if column is not None:
        data[column] = pd.to_numeric(
            data[column],
            errors="coerce")

missing_summary = pd.DataFrame({
    "Column": data.columns,
    "Missing Count": [
        data[column].isna().sum()
        for column in data.columns
        ],
    "Missing Percentage": [
        round(data[column].isna().mean() * 100,2)
        for column in data.columns]
})
print(missing_summary.to_string(index=False))
# Out:
#      Column  Missing Count  Missing Percentage
#  Time Stamp            208                 0.0
#        Step            208                 0.0
#      Status            208                 0.0
#   Prog Time            208                 0.0
#   Step Time            208                 0.0
#       Cycle            208                 0.0
# Cycle Level            208                 0.0
#   Procedure            208                 0.0
#     Voltage            211                 0.0
#     Current            211                 0.0
# Temperature            211                 0.0
#    Capacity            211                 0.0
#      WhAccu              3                 0.0
#         Cnt              4                 0.0
#   File Name              0                 0.0

# %%
duplicate_count = data.duplicated().sum()
print(
    "Total duplicate rows:",
    duplicate_count
)
if len(data) > 0:
    duplicate_percentage = (
        duplicate_count / len(data)
    ) * 100
else:
    duplicate_percentage = 0
print("Duplicate percentage:",round(duplicate_percentage,2),"%")
# Out:
# Total duplicate rows: 5876
# Duplicate percentage: 0.12 %

# %%
numeric_data = data.select_dtypes(include=np.number)
if not numeric_data.empty:
    print(numeric_data.describe().T)
else:
    print("No numeric columns found.")
# Out:
#                  count       mean        std       min       25%       50%  \
# Step         4954917.0  41.202717  24.949429   1.00000  27.00000  40.00000
# Cycle        4954917.0   1.208757   1.149936   0.00000   1.00000   1.00000
# Cycle Level  4954917.0   0.874009   0.331839   0.00000   1.00000   1.00000
# Voltage      4954914.0   3.685101   0.295787   0.00000   3.47534   3.68937
# Current      4954914.0  -1.073297   2.355671 -18.09828  -2.13522  -0.29883
# Temperature  4954914.0   8.436578  17.975277 -22.50393  -8.51784   9.25395
# Capacity     4954914.0  -1.137625   0.767443  -2.78074  -1.72840  -1.14497
#
#                   75%         max
# Step         54.00000  9999.00000
# Cycle         1.00000    10.00000
# Cycle Level   1.00000     1.00000
# Voltage       3.92823     4.23990
# Current       0.00000     6.00472
# Temperature  24.08130    41.32730
# Capacity     -0.44733     2.81804

# %%
invalid_results = []
invalid_voltage = 0
invalid_current = 0
invalid_temperature = 0
invalid_capacity = 0
invalid_soc = 0
if voltage_col is not None:
    invalid_voltage = ((data[voltage_col] <= 0) |(data[voltage_col] > 10)).sum()
    invalid_results.append({"Parameter": "Voltage","Invalid Count": invalid_voltage,"Reason": "Voltage <= 0 or unusually high voltage" })
if current_col is not None:
    invalid_current = (~np.isfinite(data[current_col])).sum()
    invalid_results.append({"Parameter": "Current","Invalid Count": invalid_current,"Reason": "Infinite or non-finite current"})
if temperature_col is not None:
    invalid_temperature = (
        (data[temperature_col] < -50) |
        (data[temperature_col] > 100)
    ).sum()
    invalid_results.append({"Parameter": "Temperature","Invalid Count": invalid_temperature,"Reason": "Temperature outside broad physical range"})
if capacity_col is not None:
    invalid_capacity = (~np.isfinite(data[capacity_col])).sum()
    invalid_results.append({"Parameter": "Capacity","Invalid Count": invalid_capacity,"Reason": "Infinite or non-finite capacity" })
if soc_col is not None:
    invalid_soc = ( (data[soc_col] < 0) |(data[soc_col] > 100)).sum()
    invalid_results.append({"Parameter": "SOC","Invalid Count": invalid_soc,"Reason": "SOC outside 0-100%"})
invalid_results_df = pd.DataFrame(invalid_results)
if not invalid_results_df.empty:
    print(invalid_results_df.to_string(index=False))
else:
    print("No applicable numeric range checks available.")
# Out:
#   Parameter  Invalid Count                                   Reason
#     Voltage              3   Voltage <= 0 or unusually high voltage
#     Current            211           Infinite or non-finite current
# Temperature              0 Temperature outside broad physical range
#    Capacity            211          Infinite or non-finite capacity

# %%
inf_results = []
for column in numeric_data.columns:
    inf_count = np.isinf(numeric_data[column]).sum()
    inf_results.append({"Column": column,"Infinite Values": inf_count})
inf_results_df = pd.DataFrame(
    inf_results
)
print(
    inf_results_df.to_string(
        index=False
    )
)
# Out:
#      Column  Infinite Values
#        Step                0
#       Cycle                0
# Cycle Level                0
#     Voltage                0
#     Current                0
# Temperature                0
#    Capacity                0

# %%
outlier_results = []
for column in numeric_data.columns:
    series = numeric_data[column].dropna()
    if len(series) < 4:
        outlier_results.append({"Column": column,"Outlier Count": 0,"Outlier Percentage": 0})
        continue
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = (
        (series < lower_bound)
        |
        (series > upper_bound)
    )
    outlier_count = outliers.sum()
    outlier_percentage = (outlier_count /len(series)) * 100
    outlier_results.append({
        "Column": column,
        "Outlier Count": outlier_count,
        "Outlier Percentage":
        round(outlier_percentage,2)})
outlier_results_df = pd.DataFrame(
    outlier_results)
print(
    outlier_results_df.to_string(
        index=False
    ))
# Out:
#      Column  Outlier Count  Outlier Percentage
#        Step             20                0.00
#       Cycle        1222120               24.66
# Cycle Level         624273               12.60
#     Voltage             43                0.00
#     Current         334288                6.75
# Temperature              0                0.00
#    Capacity          10627                0.21

# %%
if soc_col is not None:
    print("SOC target column found:",soc_col)
    print("\nSOC statistics:")
    print(data[soc_col].describe())
    print("\nSOC missing values:",data[soc_col].isna().sum())
else:
    print("SOC column is not present in the raw measurement data.")
    print("SOC should not be invented at this stage.")
    print("It can be derived or prepared later according to the project methodology.")
# Out:
# SOC column is not present in the raw measurement data.
# SOC should not be invented at this stage.
# It can be derived or prepared later according to the project methodology.

# %%
print("Available columns:")
for column in data.columns:
    print("-",column)
print("\nLeakage-related columns should be reviewed before ML.")
print("Future information or target-derived information should not be used as input features.")
# Out:
# Available columns:
# - Time Stamp
# - Step
# - Status
# - Prog Time
# - Step Time
# - Cycle
# - Cycle Level
# - Procedure
# - Voltage
# - Current
# - Temperature
# - Capacity
# - WhAccu
# - Cnt
# - File Name
#
# Leakage-related columns should be reviewed before ML.
# Future information or target-derived information should not be used as input features.

# %%
quality_results = []
for column in data.columns:
    missing_count = data[column].isna().sum()
    missing_percentage = (data[column].isna().mean()) * 100
    unique_values = (data[column].nunique(dropna=True))
    data_type = str(data[column].dtype)
    quality_results.append({
        "Column": column,
        "Data Type": data_type,
        "Missing Count": missing_count,
        "Missing %":round(missing_percentage,2),
        "Unique Values":unique_values})
quality_table = pd.DataFrame(quality_results)
print(quality_table.to_string(index=False))
# Out:
#      Column Data Type  Missing Count  Missing %  Unique Values
#  Time Stamp    object            208        0.0         577393
#        Step   float64            208        0.0             70
#      Status    object            208        0.0              5
#   Prog Time    object            208        0.0        4840467
#   Step Time    object            208        0.0        3246062
#       Cycle   float64            208        0.0             11
# Cycle Level   float64            208        0.0              2
#   Procedure    object            208        0.0              6
#     Voltage   float64            211        0.0          15825
#     Current   float64            211        0.0           8801
# Temperature   float64            211        0.0            578
#    Capacity   float64            211        0.0         265342
#      WhAccu    object              3        0.0        1149704
#         Cnt    object              4        0.0             39
#   File Name    object              0        0.0            208

# %%
for _, row in quality_table.iterrows():
    column = row["Column"]
    missing_percentage = row["Missing %"]
    if missing_percentage > 0:

        print(
            f"{column}: "
            f"{missing_percentage}% missing values")
print("\nImportant:"
)
print("Missing values should be investigated before deciding whether to remove or impute them."
)
# Out:
# Important:
# Missing values should be investigated before deciding whether to remove or impute them.

# %%
cleaning_rules = [

    ("Metadata rows","Remove metadata rows before analysis"),
    ("Units row","Remove units row from measurement data"),
    ("Column names","Standardize column names"),
    ("Non-numeric values","Convert valid measurement values to numeric and flag invalid entries"),
    ("Missing values","Quantify and investigate before treatment"),
    ("Invalid measurements", "Flag values outside physically meaningful ranges"),
    ("Outliers","Flag statistical outliers and investigate before removal"),
    ("Target leakage","Remove future or target-derived information from input features"),
    ("Train/test contamination","Use cycle/session-aware splitting where appropriate"),
    ("Different file structures","Convert files into a common measurement schema")
]
cleaning_rules_df = pd.DataFrame(
    cleaning_rules,
    columns=["Issue","Proposed Action"]
)
print(
    cleaning_rules_df.to_string(
        index=False)
)
# Out:
#                     Issue                                                      Proposed Action
#             Metadata rows                                 Remove metadata rows before analysis
#                 Units row                               Remove units row from measurement data
#              Column names                                             Standardize column names
#        Non-numeric values Convert valid measurement values to numeric and flag invalid entries
#            Missing values                            Quantify and investigate before treatment
#      Invalid measurements                     Flag values outside physically meaningful ranges
#                  Outliers             Flag statistical outliers and investigate before removal
#            Target leakage      Remove future or target-derived information from input features
#  Train/test contamination                  Use cycle/session-aware splitting where appropriate
# Different file structures                       Convert files into a common measurement schema

# %%
print(" EXPECTED DATA QUALITY AFTER CLEANING")
print("Expected improvements:")
print("1. Consistent measurement structure across all CSV files")
print("2. Metadata separated from measurement data")
print("3. Correct numeric data types")
print("4. Missing values identified and treated appropriately")
print("5. Duplicate records identified")
print("6. Abnormal measurements flagged")
print("7. Potential leakage reduced")
print("8. Dataset prepared for later ML modelling")
# Out:
#  EXPECTED DATA QUALITY AFTER CLEANING
# Expected improvements:
# 1. Consistent measurement structure across all CSV files
# 2. Metadata separated from measurement data
# 3. Correct numeric data types
# 4. Missing values identified and treated appropriately
# 5. Duplicate records identified
# 6. Abnormal measurements flagged
# 7. Potential leakage reduced
# 8. Dataset prepared for later ML modelling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
if (
    voltage_col is not None
    and current_col is not None
):
    plot_data = data[[voltage_col,current_col]].dropna()
    if len(plot_data) > 0:
        plt.figure(figsize=(8, 5))
        plt.scatter( plot_data[voltage_col],plot_data[current_col],alpha=0.5,s=10)
        plt.xlabel("Voltage")
        plt.ylabel("Current")
        plt.title("Battery Operating Region: Voltage vs Current")
        plt.grid(True,alpha=0.3)
        plt.tight_layout()
        plt.show()
    else:
        print("Graph skipped: No valid Voltage/Current data.")
else:
    print(
        "Graph skipped: Voltage or Current column not found.")

# %%
if (
    temperature_col is not None
    and capacity_col is not None
):
    plot_data = data[[temperature_col,capacity_col]].dropna()
    if len(plot_data) > 0:
        plt.figure(figsize=(8, 5))
        plt.scatter(
            plot_data[temperature_col],
            plot_data[capacity_col],
            alpha=0.5,
            s=10)
        plt.xlabel("Temperature")
        plt.ylabel("Capacity")
        plt.title("Temperature vs Capacity")
        plt.grid(True,alpha=0.3)
        plt.tight_layout()
        plt.show()
    else:
        print("Graph skipped: No valid Temperature/Capacity data.")
else:
    print("Graph skipped: Temperature or Capacity column not found.")

# %%
if voltage_col is not None:
    voltage_data = data[voltage_col].dropna()
    if len(voltage_data) > 0:
        plt.figure(figsize=(8, 5))
        plt.hist(voltage_data,bins=50)
        plt.xlabel("Voltage")
        plt.ylabel("Frequency")
        plt.title("Voltage Distribution Across Dataset")
        plt.grid(True,alpha=0.3)
        plt.tight_layout()
        plt.show()
    else:
        print("Graph skipped: No valid voltage data.")
else:
    print("Graph skipped: Voltage column not found.")

# %%
if temperature_col is not None:
    temperature_data = data[
        temperature_col
    ].dropna()
    if len(temperature_data) > 0:
        plt.figure(figsize=(8, 5))
        plt.hist(temperature_data,bins=50)
        plt.xlabel("Temperature")
        plt.ylabel("Frequency")
        plt.title("Temperature Distribution Across Dataset")
        plt.grid(True,alpha=0.)
        plt.tight_layout()
        plt.show()

    else:
        print("Graph skipped: No valid temperature data.")
else:
    print("Graph skipped: Temperature column not found.")

# %%
import matplotlib.pyplot as plt
if soc_col is not None:
    soc_data = data[soc_col].dropna()
    if len(soc_data) > 0:
        plt.figure(figsize=(8, 5))
        plt.hist(soc_data,bins=50)
        plt.xlabel("SOC (%)")
        plt.ylabel("Frequency")

        plt.title("SOC Distribution")
        plt.grid(True,lpha=0.3)
        plt.tight_layout()
        plt.show()
    else:
        print("Graph skipped: SOC column exists but contains no valid data.")
else:
    print("SOC distribution graph skipped because SOC is not present in the raw dataset.")
# Out:
# SOC distribution graph skipped because SOC is not present in the raw dataset.

# %%
dataset_path = "/content/drive/MyDrive/BATTERY_SOC_PROJECT/SOC DATA SET/Dataset_Li-ion/"

report_path = os.path.join(
    dataset_path,
    "Day_8_Data_Quality_Reports"
)
os.makedirs(
    report_path,
    exist_ok=True
)


file_summary_df.to_csv(
    os.path.join(report_path,"file_summary.csv"),index=False)


missing_summary.to_csv(
    os.path.join(report_path,"missing_values_report.csv"),index=False)

quality_table.to_csv(
    os.path.join(report_path,"feature_quality_report.csv"),index=False)
if not invalid_results_df.empty:
    invalid_results_df.to_csv(
        os.path.join(report_path,"invalid_values_report.csv"),index=False)

duplicate_summary = pd.DataFrame({
    "Metric": [
        "Total Rows",
        "Duplicate Rows",
        "Duplicate Percentage"
    ],
    "Value": [len(data),duplicate_count,round(duplicate_percentage,2)]
})
duplicate_summary.to_csv(
    os.path.join(report_path,"duplicate_report.csv"),index=False)
outlier_results_df.to_csv(
    os.path.join(report_path,"outlier_report.csv"),index=False)
cleaning_rules_df.to_csv(
    os.path.join(report_path,"proposed_cleaning_rules.csv"),index=False)
print("\nReports saved successfully!")
print("\nReport folder:")
print(report_path)
# Out:
# Reports saved successfully!
#
# Report folder:
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/SOC DATA SET/Dataset_Li-ion/Day_8_Data_Quality_Reports

# %%
print(" FINAL SUMMARY")
print( "\nTotal CSV files found:",len(csv_files))
print("Successfully loaded:",len(dataframes))
print("Total combined measurement rows:",len(data))
print("Total columns:",len(data.columns))
print("Duplicate rows:",duplicate_count)
print("Reports saved to:")
print(report_path)
# Out:
#  FINAL SUMMARY
#
# Total CSV files found: 208
# Successfully loaded: 208
# Total combined measurement rows: 4955125
# Total columns: 15
# Duplicate rows: 5876
# Reports saved to:
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/SOC DATA SET/Dataset_Li-ion/Day_8_Data_Quality_Reports
