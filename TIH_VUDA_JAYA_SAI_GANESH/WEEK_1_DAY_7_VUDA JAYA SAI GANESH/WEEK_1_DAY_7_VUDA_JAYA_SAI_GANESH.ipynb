# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
path = "/content/drive/MyDrive/BATTERY_SOC_PROJECT"
os.listdir(path)
# Out:
# ['Dataset_Li-ion']

# %%
files = os.listdir("/content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion")
print(files)
# Out:
# ['utils.py', 'Technical Information and Experimental Test Results for LG 18650HG2.pdf', 'Readme file - Description of Experimental Tests.txt', 'n10degC', '25degC', 'n20degC', '0degC', '10degC', '40degC']

# %%
base_path = "/content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion"
print(os.listdir(base_path + "/0degC"))
# Out:
# ['589_HWFET.csv', '589_LA92.csv', '589_Charge3.csv', '590_Charge13.csv', '585_C20DisCh.csv', '585_Dis_2C.csv', '590_Charge16.csv', '589_Charge2.csv', '590_Charge14.csv', '589_Charge8.csv', '590_Mixed4.csv', '585_HPPC.csv', '589_Mixed2.csv', '589_UDDS.csv', '589_Charge6.csv', '590_Charge15.csv', '589_Charge1.csv', '589_Cap_1C.csv', '590_Charge10.csv', '589_Charge4.csv', '590_Charge12.csv', '585_Dis_0p5C.csv', '589_Charge7.csv', '590_Mixed6.csv', '589_US06.csv', '590_Mixed5.csv', '589_Charge5.csv', '589_Mixed1.csv', '590_Charge11.csv', '590_Mixed7.csv', '590_Mixed8.csv', '590_PausCycl.csv']

# %%
import os
import pandas as pd
base_path = "/content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion"
temperature_folders = ["0degC","10degC","25degC","40degC","n10degC","n20degC"]
print("Dataset path:")
print(base_path)
print("\nChecking temperature folders")
for folder in temperature_folders:
    folder_path = os.path.join(base_path, folder)
    if os.path.exists(folder_path):
        print(folder, "- Found")
    else:
        print(folder, "- Not Found")
# Out:
# Dataset path:
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/Dataset_Li-ion
#
# Checking temperature folders
# 0degC - Found
# 10degC - Found
# 25degC - Found
# 40degC - Found
# n10degC - Found
# n20degC - Found

# %%
print("\nCSV files in each folder")
total_files = 0
for folder in temperature_folders:
    folder_path = os.path.join(base_path, folder)
    files = os.listdir(folder_path)
    count = 0
    for file in files:
        if file.endswith(".csv"):
            count = count + 1
    print(folder, ":", count, "CSV files")
    total_files = total_files + count
print("\nTotal CSV files:", total_files)
# Out:
# CSV files in each folder
# 0degC : 32 CSV files
# 10degC : 32 CSV files
# 25degC : 36 CSV files
# 40degC : 35 CSV files
# n10degC : 38 CSV files
# n20degC : 35 CSV files
#
# Total CSV files: 208

# %%
file_path = os.path.join(
    base_path,
    "0degC",
    "589_Charge1.csv")
print("First 35 lines of the original CSV")
with open(file_path, "r") as file:
    for i in range(35):
        line = file.readline()
        print(i + 1, ":", line.strip())
# Out:
# First 35 lines of the original CSV
# 1 :
# 2 :
# 3 : Measurement ID,589
# 4 : Battery Name,LG HG2 18650_SN62A4
# 5 : Battery Type,Li-ion
# 6 : Circuit,Circuit001
# 7 : Program,1747 - LG_HG2_CyclesA
# 8 : Start Time,11/29/2018 6:52:45 PM
# 9 : End Time,12/1/2018 9:57:38 AM
# 10 : Test section,Charge1
# 11 : Comment,
# 12 : OrderNo,
# 13 : Producer, LG
# 14 : Type, Li-ion
# 15 : Nominal Voltage, 3.7
# 16 : Nominal Current, 3
# 17 : Nominal Capacity, 3
# 18 : Cells, 1
# 19 : Maximum Voltage, 4.2
# 20 : Gassing Voltage, 0
# 21 : Break Voltage, 0
# 22 : Charge Factor, 0
# 23 : Impedance, 0.02
# 24 : Cold Cranking Current, 0
# 25 : Energy Density, 0
# 26 : Comment,HG2 cell with 10AWG wire soldered  to cell
# 27 :
# 28 :
# 29 : Time Stamp,Step,Status,Prog Time,Step Time,Cycle,Cycle Level,Procedure,Voltage,Current,Temperature,Capacity,WhAccu,Cnt,
# 30 : ,,,,,,,,[V],[A],[C],[Ah],[Wh],[Cnt],
# 31 : 11/29/2018 6:53:50 PM,3,PAU,00:01:05.029,00:01:00.003,0,0,NN_Char_Charge,4.18799,0.00000,1.15674,0.00000,0.00000,1.00000,
# 32 : 11/29/2018 6:54:50 PM,3,PAU,00:02:05.027,00:02:00.001,0,0,NN_Char_Charge,4.18799,0.00000,4.20634,0.00000,0.00000,1.00000,
# 33 : 11/29/2018 6:55:50 PM,3,PAU,00:03:05.026,00:03:00.000,0,0,NN_Char_Charge,4.18815,0.00000,7.78173,0.00000,0.00000,1.00000,
# 34 : 11/29/2018 6:56:50 PM,3,PAU,00:04:05.028,00:04:00.002,0,0,NN_Char_Charge,4.18849,0.00000,11.35712,0.00000,0.00000,1.00000,
# 35 : 11/29/2018 6:57:50 PM,3,PAU,00:05:05.028,00:05:00.002,0,0,NN_Char_Charge,4.18866,0.00000,15.14283,0.00000,0.00000,1.00000,

# %%
print("\nInspecting all CSV files")
results = []
for folder in temperature_folders:
    folder_path = os.path.join(base_path, folder)
    for file in os.listdir(folder_path):
        if file.endswith(".csv"):
            file_path = os.path.join(folder_path, file)
            data = pd.read_csv(
                file_path,
                skiprows=28,
                low_memory=False)
            data = data.iloc[1:].copy()
            rows = data.shape[0]
            columns = data.shape[1]
            missing = data.isnull().sum().sum()
            duplicates = data.duplicated().sum()
            results.append([
                folder,
                file,
                rows,
                columns,
                missing,
                duplicates])
print("Inspection completed.")
print("Files inspected:", len(results))
# Out:
# Inspecting all CSV files
# Inspection completed.
# Files inspected: 208

# %%
inspection = pd.DataFrame(
    results,
    columns=["Temperature","File","Rows","Columns","Missing Values","Duplicate Rows"])
display(inspection)
# Out:
#     Temperature              File   Rows  Columns  Missing Values  \
# 0         0degC     589_HWFET.csv  49678       15           49678
# 1         0degC      589_LA92.csv  81577       15           81577
# 2         0degC   589_Charge3.csv    206       15             206
# 3         0degC  590_Charge13.csv    205       15             205
# 4         0degC  585_C20DisCh.csv   2244       15            2244
# ..          ...               ...    ...      ...             ...
# 203     n20degC  611_Charge15.csv    190       15             190
# 204     n20degC   610_Charge2.csv    193       15             193
# 205     n20degC   610_Charge4.csv    190       15             190
# 206     n20degC  611_PausCycl.csv  16617       15           16617
# 207     n20degC    611_Mixed8.csv  46763       15           46763
#
#      Duplicate Rows
# 0                 1
# 1                 0
# 2                 2
# 3                 2
# 4                 1
# ..              ...
# 203               2
# 204               2
# 205               3
# 206               0
# 207               1
#
# [208 rows x 6 columns]

# %%
print("Dataset Summary")
print("Total CSV files:", len(inspection))
print("\nFiles in each temperature folder:")
for folder in temperature_folders:
    count = 0
    for value in inspection["Temperature"]:
        if value == folder:
            count = count + 1
    print(folder, ":", count)
# Out:
# Dataset Summary
# Total CSV files: 208
#
# Files in each temperature folder:
# 0degC : 32
# 10degC : 32
# 25degC : 36
# 40degC : 35
# n10degC : 38
# n20degC : 35

# %%
print("\nMissing Values:-")
total_missing = inspection["Missing Values"].sum()
print("Total missing values:", total_missing)
print("\nDuplicate Rows:-")
total_duplicates = inspection["Duplicate Rows"].sum()
print("Total duplicate rows:", total_duplicates)
# Out:
# Missing Values:-
# Total missing values: 4954079
#
# Duplicate Rows:-
# Total duplicate rows: 5876

# %%
file_path = os.path.join(base_path,"0degC","589_Charge1.csv")
data = pd.read_csv(file_path,skiprows=28,
low_memory=False)
data = data.iloc[1:].copy()
print("Example file:")
print("0degC / 589_Charge1.csv")
print("\nFirst 5 rows:")
display(data.head())
print("\nShape:")
print(data.shape)
print("\nColumn names:")
print(data.columns.tolist())
print("\nData types:")
print(data.dtypes)
# Out:
# Example file:
# 0degC / 589_Charge1.csv
#
# First 5 rows:
#               Time Stamp  Step Status     Prog Time     Step Time  Cycle  \
# 1  11/29/2018 6:53:50 PM   3.0    PAU  00:01:05.029  00:01:00.003    0.0
# 2  11/29/2018 6:54:50 PM   3.0    PAU  00:02:05.027  00:02:00.001    0.0
# 3  11/29/2018 6:55:50 PM   3.0    PAU  00:03:05.026  00:03:00.000    0.0
# 4  11/29/2018 6:56:50 PM   3.0    PAU  00:04:05.028  00:04:00.002    0.0
# 5  11/29/2018 6:57:50 PM   3.0    PAU  00:05:05.028  00:05:00.002    0.0
#
#    Cycle Level       Procedure  Voltage  Current Temperature Capacity  \
# 1          0.0  NN_Char_Charge  4.18799  0.00000     1.15674  0.00000
# 2          0.0  NN_Char_Charge  4.18799  0.00000     4.20634  0.00000
# 3          0.0  NN_Char_Charge  4.18815  0.00000     7.78173  0.00000
# 4          0.0  NN_Char_Charge  4.18849  0.00000    11.35712  0.00000
# 5          0.0  NN_Char_Charge  4.18866  0.00000    15.14283  0.00000
#
#     WhAccu      Cnt  Unnamed: 14
# 1  0.00000  1.00000          NaN
# 2  0.00000  1.00000          NaN
# 3  0.00000  1.00000          NaN
# 4  0.00000  1.00000          NaN
# 5  0.00000  1.00000          NaN
# Shape:
# (131, 15)
#
# Column names:
# ['Time Stamp', 'Step', 'Status', 'Prog Time', 'Step Time', 'Cycle', 'Cycle Level', 'Procedure', 'Voltage', 'Current', 'Temperature', 'Capacity', 'WhAccu', 'Cnt', 'Unnamed: 14']
#
# Data types:
# Time Stamp      object
# Step           float64
# Status          object
# Prog Time       object
# Step Time       object
# Cycle          float64
# Cycle Level    float64
# Procedure       object
# Voltage         object
# Current         object
# Temperature     object
# Capacity        object
# WhAccu          object
# Cnt             object
# Unnamed: 14    float64
# dtype: object

# %%
print("Basic Statistics")
display(data.describe())
# Out:
# Basic Statistics
#              Step  Cycle  Cycle Level  Unnamed: 14
# count  131.000000  131.0        131.0          0.0
# mean     5.984733    0.0          0.0          NaN
# std      3.065904    0.0          0.0          NaN
# min      3.000000    0.0          0.0          NaN
# 25%      3.000000    0.0          0.0          NaN
# 50%      4.000000    0.0          0.0          NaN
# 75%      9.000000    0.0          0.0          NaN
# max     16.000000    0.0          0.0          NaN

# %%
print("Checking for SOC or target columns")
soc_found = False
for folder in temperature_folders:
    folder_path = os.path.join(base_path, folder)
    for file in os.listdir(folder_path):
        if file.endswith(".csv"):
            file_path = os.path.join(folder_path, file)
            data = pd.read_csv(
                file_path,
                skiprows=28,
                low_memory=False)
            data = data.iloc[1:].copy()
            for column in data.columns:
                if "SOC" in str(column).upper():
                    print("SOC column found:", column)
                    soc_found = True
if soc_found == False:
    print("No direct SOC column was found.")
# Out:
# Checking for SOC or target columns
# No direct SOC column was found.

# %%
print("Invalid numerical data check")
columns_to_check = ["Voltage","Current","Temperature","Capacity","WhAccu"]
invalid_total = 0
for folder in temperature_folders:
    folder_path = os.path.join(base_path, folder)
    for file in os.listdir(folder_path):
        if file.endswith(".csv"):
            file_path = os.path.join(folder_path, file)
            data = pd.read_csv(
                file_path,
                skiprows=28,
                low_memory=False
            )
            data = data.iloc[1:].copy()
            for column in columns_to_check:
                if column in data.columns:
                    original = data[column]
                    converted = pd.to_numeric(
                        original,
                        errors="coerce"
                    )
                    invalid = (
                        original.notna() &
                        converted.isna()
                    ).sum()
                    if invalid > 0:
                        print(
                            folder,
                            file,
                            column,
                            ":", invalid,
                            "invalid values"
                        )
                        invalid_total = invalid_total + invalid
print("\nTotal invalid values:", invalid_total)
# Out:
# Invalid numerical data check
#
# Total invalid values: 0

# %%
print("Simple consistency check")
problem_files = 0
for folder in temperature_folders:
    folder_path = os.path.join(base_path, folder)
    for file in os.listdir(folder_path):
        if file.endswith(".csv"):
            file_path = os.path.join(folder_path, file)
            data = pd.read_csv(
                file_path,
                skiprows=28,
                low_memory=False
            )
            data = data.iloc[1:].copy()
            if "Voltage" in data.columns:
                voltage = pd.to_numeric(
                    data["Voltage"],
                    errors="coerce"
                )
                if (voltage <= 0).any():
                    print(
                        "Non-positive voltage found:",
                        folder,
                        file
                    )
                    problem_files = problem_files + 1
print("\nFiles with non-positive voltage:", problem_files)
# Out:
# Simple consistency check
# Non-positive voltage found: 0degC 590_Charge16.csv
# Non-positive voltage found: 25degC 552_Charge16.csv
# Non-positive voltage found: 40degC 557_Charge10.csv
#
# Files with non-positive voltage: 3

# %%
report_folder = "/content/drive/MyDrive/BATTERY_SOC_PROJECT/SOC DATA SET/Day_7_Reports"
os.makedirs(report_folder, exist_ok=True)
inspection_file = os.path.join(
    report_folder,"Day7_Complete_File_Inspection.csv")
inspection.to_csv(
    inspection_file,
    index=False
)
print("Inspection report saved:")
print(inspection_file)
# Out:
# Inspection report saved:
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/SOC DATA SET/Day_7_Reports/Day7_Complete_File_Inspection.csv

# %%
summary = []
for folder in temperature_folders:
    folder_data = inspection[
        inspection["Temperature"] == folder
    ]
    number_of_files = len(folder_data)
    total_rows = folder_data["Rows"].sum()
    total_missing = folder_data["Missing Values"].sum()
    total_duplicates = folder_data["Duplicate Rows"].sum()
    summary.append([
        folder,
        number_of_files,
        total_rows,
        total_missing,
        total_duplicates
    ])
temperature_summary = pd.DataFrame(
    summary,
    columns=["Temperature","Number of Files","Total Rows","Total Missing Values","Total Duplicate Rows"])
display(temperature_summary)
summary_file = os.path.join(
    report_folder,
    "Day7_Temperature_Summary.csv"
)
temperature_summary.to_csv(
    summary_file,
    index=False
)
print("\nTemperature summary saved:")
print(summary_file)
# Out:
#   Temperature  Number of Files  Total Rows  Total Missing Values  \
# 0       0degC               32      850622                850622
# 1      10degC               32      925533                925552
# 2      25degC               36     1045475               1044620
# 3      40degC               35      692629                692629
# 4     n10degC               38      829826                829826
# 5     n20degC               35      610830                610830
#
#    Total Duplicate Rows
# 0                   232
# 1                   456
# 2                   287
# 3                   269
# 4                  4398
# 5                   234
# Temperature summary saved:
# /content/drive/MyDrive/BATTERY_SOC_PROJECT/SOC DATA SET/Day_7_Reports/Day7_Temperature_Summary.csv
